# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np 
import seaborn as sns
sns.set(rc={'figure.figsize':(20,8)})
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})
pd.set_option('display.max_rows', 120)

# %% [markdown]
# ## Reading / Displaying the Data

# %%
df_sales = pd.read_csv('../data/clean_step2.csv')

# %%
df_sales.head()
# Out:
#                            order_id                              code  \
# 0  bcb59c839e78b2601374cbad9239ca7b  e6762ba2ffbca07ab6cee7551caeaad5
# 1  88eb0ac86af1a521c0831298d22dea8b  e6762ba2ffbca07ab6cee7551caeaad5
# 2  1c175bc61b9b659bbf011b2e5e3dcec6  e6762ba2ffbca07ab6cee7551caeaad5
# 3  a8ad36828898fa3f6efeb5bd19c076f2  e6762ba2ffbca07ab6cee7551caeaad5
# 4  9cbfaac6e04ea6ed454b843c94f2c29c  e6762ba2ffbca07ab6cee7551caeaad5
#
#    quantity    price  pis_cofins     icms  tax_substitution  \
# 0         1   978.90     90.5483    0.000          191.8416
# 1         1   978.90     90.5483    0.000          191.8416
# 2         1   976.05     90.2846    0.000          192.3325
# 3         1  1089.10    100.7418  185.147            0.0000
# 4         1   949.00     87.7825  170.820            0.0000
#
#                            category  liquid_cost   order_status  ...  \
# 0  4ece547755cba9e7fc14125bc895f31b     542.7065  entrega total  ...
# 1  4ece547755cba9e7fc14125bc895f31b     542.7065  entrega total  ...
# 2  4ece547755cba9e7fc14125bc895f31b     542.7065  entrega total  ...
# 3  4ece547755cba9e7fc14125bc895f31b     542.7065  entrega total  ...
# 4  4ece547755cba9e7fc14125bc895f31b     542.7065  entrega total  ...
#
#   perc_icms perc_tax_substitution unit_revenue unit_price  unit_liquid_price  \
# 0       0.0                 19.60     537.4868     978.90          1080.1933
# 1       0.0                 19.60     537.4868     978.90          1080.1933
# 2       0.0                 19.71     535.3914     976.05          1078.0979
# 3      17.0                  0.00     260.5047    1089.10           803.2112
# 4      18.0                  0.00     147.6910     949.00           690.3975
#
#    unit_perc_pis_cofins  unit_perc_icms  unit_perc_tax_substitution  \
# 0                  9.25             0.0                       19.60
# 1                  9.25             0.0                       19.60
# 2                  9.25             0.0                       19.71
# 3                  9.25            17.0                        0.00
# 4                  9.25            18.0                        0.00
#
#    unit_liquid_cost  unit_markup
# 0          542.7065     1.990382
# 1          542.7065     1.990382
# 2          542.7065     1.986521
# 3          542.7065     1.480010
# 4          542.7065     1.272138
#
# [5 rows x 30 columns]

# %%
df_sales.columns
# Out:
# Index(['order_id', 'code', 'quantity', 'price', 'pis_cofins', 'icms',
#        'tax_substitution', 'category', 'liquid_cost', 'order_status',
#        'capture_date', 'process_date', 'process_status', 'source_channel',
#        'liquid_price', 'revenue', 'markup', 'week_number', 'month',
#        'perc_pis_cofins', 'perc_icms', 'perc_tax_substitution', 'unit_revenue',
#        'unit_price', 'unit_liquid_price', 'unit_perc_pis_cofins',
#        'unit_perc_icms', 'unit_perc_tax_substitution', 'unit_liquid_cost',
#        'unit_markup'],
#       dtype='object')

# %%
df_sales['unit_liquid_cost_perc'] = df_sales['unit_liquid_cost'] / df_sales['unit_liquid_price']

# %% [markdown]
# ## Adding some features and grouping it by product code

# %% [markdown]
# #### Previous analysis insights / hipothesis
# * Seasonality plays a great influence (month, week number), so lets add some more fields following the same tought

# %%
df_sales['capture_date'] = pd.to_datetime(df_sales['capture_date'], errors='coerce')
df_sales['weekend'] = df_sales.capture_date.dt.dayofweek.apply(lambda x: 1 if x in [0,6] else 0)
df_sales['week_of_month'] = df_sales.capture_date.dt.day.apply(lambda x: (x % 4) + 1)
df_sales['quarter'] = df_sales.capture_date.dt.month.apply(lambda x: (x % 4) + 1)

# %%
df_sales.head()
# Out:
#                            order_id                              code  \
# 0  bcb59c839e78b2601374cbad9239ca7b  e6762ba2ffbca07ab6cee7551caeaad5
# 1  88eb0ac86af1a521c0831298d22dea8b  e6762ba2ffbca07ab6cee7551caeaad5
# 2  1c175bc61b9b659bbf011b2e5e3dcec6  e6762ba2ffbca07ab6cee7551caeaad5
# 3  a8ad36828898fa3f6efeb5bd19c076f2  e6762ba2ffbca07ab6cee7551caeaad5
# 4  9cbfaac6e04ea6ed454b843c94f2c29c  e6762ba2ffbca07ab6cee7551caeaad5
#
#    quantity    price  pis_cofins     icms  tax_substitution  \
# 0         1   978.90     90.5483    0.000          191.8416
# 1         1   978.90     90.5483    0.000          191.8416
# 2         1   976.05     90.2846    0.000          192.3325
# 3         1  1089.10    100.7418  185.147            0.0000
# 4         1   949.00     87.7825  170.820            0.0000
#
#                            category  liquid_cost   order_status  ...  \
# 0  4ece547755cba9e7fc14125bc895f31b     542.7065  entrega total  ...
# 1  4ece547755cba9e7fc14125bc895f31b     542.7065  entrega total  ...
# 2  4ece547755cba9e7fc14125bc895f31b     542.7065  entrega total  ...
# 3  4ece547755cba9e7fc14125bc895f31b     542.7065  entrega total  ...
# 4  4ece547755cba9e7fc14125bc895f31b     542.7065  entrega total  ...
#
#   unit_liquid_price unit_perc_pis_cofins unit_perc_icms  \
# 0         1080.1933                 9.25            0.0
# 1         1080.1933                 9.25            0.0
# 2         1078.0979                 9.25            0.0
# 3          803.2112                 9.25           17.0
# 4          690.3975                 9.25           18.0
#
#   unit_perc_tax_substitution  unit_liquid_cost  unit_markup  \
# 0                      19.60          542.7065     1.990382
# 1                      19.60          542.7065     1.990382
# 2                      19.71          542.7065     1.986521
# 3                       0.00          542.7065     1.480010
# 4                       0.00          542.7065     1.272138
#
#    unit_liquid_cost_perc  weekend  week_of_month  quarter
# 0               0.502416        0              4        3
# 1               0.502416        1              1        3
# 2               0.503393        1              2        3
# 3               0.675671        1              2        3
# 4               0.786078        0              3        3
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Keeping most relevant fields
# * The object is to understand the price behaviour, offer and demand. Given that we are removing some total fields and keeping those focused on units and season.

# %%
df_sales.columns
# Out:
# Index(['order_id', 'code', 'quantity', 'price', 'pis_cofins', 'icms',
#        'tax_substitution', 'category', 'liquid_cost', 'order_status',
#        'capture_date', 'process_date', 'process_status', 'source_channel',
#        'liquid_price', 'revenue', 'markup', 'week_number', 'month',
#        'perc_pis_cofins', 'perc_icms', 'perc_tax_substitution', 'unit_revenue',
#        'unit_price', 'unit_liquid_price', 'unit_perc_pis_cofins',
#        'unit_perc_icms', 'unit_perc_tax_substitution', 'unit_liquid_cost',
#        'unit_markup', 'unit_liquid_cost_perc', 'weekend', 'week_of_month',
#        'quarter'],
#       dtype='object')

# %%
# df_sales = df_sales[base_cols]

# %%
df_sales.head()
# Out:
#                            order_id                              code  \
# 0  bcb59c839e78b2601374cbad9239ca7b  e6762ba2ffbca07ab6cee7551caeaad5
# 1  88eb0ac86af1a521c0831298d22dea8b  e6762ba2ffbca07ab6cee7551caeaad5
# 2  1c175bc61b9b659bbf011b2e5e3dcec6  e6762ba2ffbca07ab6cee7551caeaad5
# 3  a8ad36828898fa3f6efeb5bd19c076f2  e6762ba2ffbca07ab6cee7551caeaad5
# 4  9cbfaac6e04ea6ed454b843c94f2c29c  e6762ba2ffbca07ab6cee7551caeaad5
#
#    quantity    price  pis_cofins     icms  tax_substitution  \
# 0         1   978.90     90.5483    0.000          191.8416
# 1         1   978.90     90.5483    0.000          191.8416
# 2         1   976.05     90.2846    0.000          192.3325
# 3         1  1089.10    100.7418  185.147            0.0000
# 4         1   949.00     87.7825  170.820            0.0000
#
#                            category  liquid_cost   order_status  ...  \
# 0  4ece547755cba9e7fc14125bc895f31b     542.7065  entrega total  ...
# 1  4ece547755cba9e7fc14125bc895f31b     542.7065  entrega total  ...
# 2  4ece547755cba9e7fc14125bc895f31b     542.7065  entrega total  ...
# 3  4ece547755cba9e7fc14125bc895f31b     542.7065  entrega total  ...
# 4  4ece547755cba9e7fc14125bc895f31b     542.7065  entrega total  ...
#
#   unit_liquid_price unit_perc_pis_cofins unit_perc_icms  \
# 0         1080.1933                 9.25            0.0
# 1         1080.1933                 9.25            0.0
# 2         1078.0979                 9.25            0.0
# 3          803.2112                 9.25           17.0
# 4          690.3975                 9.25           18.0
#
#   unit_perc_tax_substitution  unit_liquid_cost  unit_markup  \
# 0                      19.60          542.7065     1.990382
# 1                      19.60          542.7065     1.990382
# 2                      19.71          542.7065     1.986521
# 3                       0.00          542.7065     1.480010
# 4                       0.00          542.7065     1.272138
#
#    unit_liquid_cost_perc  weekend  week_of_month  quarter
# 0               0.502416        0              4        3
# 1               0.502416        1              1        3
# 2               0.503393        1              2        3
# 3               0.675671        1              2        3
# 4               0.786078        0              3        3
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Verify the distributions

# %%
def summary_dist(target_col, base_col='order_id', method='count'):
    if method == 'count':
        df_summary = df_sales[[target_col,base_col]].groupby(target_col).agg({base_col:pd.Series.nunique}).reset_index()
    else:
        df_summary = df_sales[[target_col,base_col]].groupby(target_col).agg({base_col:pd.Series.sum}).reset_index()
    df_summary[base_col] = df_summary[base_col] / df_summary[base_col].sum()  * 100
    return df_summary.sort_values(base_col).tail(25)

# %%
df_week_of_month = summary_dist('week_of_month').sort_values('week_of_month')
df_week_of_month
# Out:
#    week_of_month   order_id
# 0              1  22.273294
# 1              2  27.748175
# 2              3  26.815517
# 3              4  23.163015

# %% [markdown]
# * Sales tend to concentrate on the middle of the months?

# %%
df_weekend = summary_dist('weekend')
df_weekend
# Out:
#    weekend   order_id
# 1        1  25.347195
# 0        0  74.652805

# %% [markdown]
# * Considering 2 / 7  the proportion non biased would be around 28.57% on weekends.

# %% [markdown]
# ### Simple Checks

# %%
df_sales[['code', 'category']].groupby('code').nunique().reset_index().sort_values('category').tail(10)
# Out:
#                                  code  category
# 41   411e1404e183718207628232e91ce5a9         1
# 40   40d98a2375332cb635d4cb28ab68e087         1
# 39   40bddb00475d65eddb68e9aeb6fab0de         1
# 38   3da22f1b88a20ea8efc3d83fcb872e21         1
# 37   3d3d13446c52ecaaed5d0bf55a933d4d         1
# 36   3d21b63892749e921e3ff5818753bd67         1
# 35   3bc993e0f0c636e9aaaefa0356bdecc0         1
# 34   3b4407288e2983a514a241c9b84b7094         1
# 32   390943ce05959ac98c702d250c2ebb54         1
# 129  ffdad3ddbaf6c76c9bba1b48c51e03c6         1

# %% [markdown]
# * There is only a category per product so we can keep a category field for it.

# %%
df_sales['cat_code'] = df_sales.category.astype('category').cat.codes

# %%
source_channel = df_sales[['code', 'source_channel']].groupby('code').nunique().reset_index().sort_values('source_channel')
source_channel.tail(10)
# Out:
#                                  code  source_channel
# 25   32ceebf3efea1d04ace4183d20d4da5b              12
# 26   3454ea52396a4cfd3fc37414d30c7b9c              12
# 129  ffdad3ddbaf6c76c9bba1b48c51e03c6              12
# 77   727673fa3e457bc596532b3eb26b23a0              12
# 116  d57911cca4b08f7b46417d952c0ca1dc              12
# 119  dd1935ffd0ee2b6ec159ba7867d11e57              12
# 79   760693745e10b0c5e68c42214c729b0d              13
# 44   4534ea61b50410b3b6243e02b40c8cd1              13
# 61   5b7a30a9e6a43b170ad4d9e00d8d9359              13
# 23   2e35421c34fb588ba40a0c57b3971d24              14

# %% [markdown]
#  * one sale could come from any source, so there is a need of quantify the ammount of sales per each of the all channels.

# %% [markdown]
# ## Sumarizing behaviours

# %%
df_products = df_sales[['code', 'cat_code']].drop_duplicates().set_index('code')
df_products
# Out:
#                                   cat_code
# code
# e6762ba2ffbca07ab6cee7551caeaad5         1
# d408e1b5e841dde4e15a4cfa182e3812         5
# 29424aaf6e27a8dbe4b7273a0a39131d         5
# 723f73c85e91fc31d147dfade389d4f9         0
# 54209126056016c7c391c0c8fd8e6eff         0
# ...                                    ...
# b272ba3f4adb1dd16eaac1b53940629e         5
# 727673fa3e457bc596532b3eb26b23a0         0
# d5bc9e14d090330cd07e6ccbcb3c3e4e         0
# b9d929195dcd4e6a36e5e65891746b5e         0
# 1c234775cae774823f38abe6721e61a4         0
#
# [130 rows x 1 columns]

# %%
df_sales.columns
# Out:
# Index(['order_id', 'code', 'quantity', 'price', 'pis_cofins', 'icms',
#        'tax_substitution', 'category', 'liquid_cost', 'order_status',
#        'capture_date', 'process_date', 'process_status', 'source_channel',
#        'liquid_price', 'revenue', 'markup', 'week_number', 'month',
#        'perc_pis_cofins', 'perc_icms', 'perc_tax_substitution', 'unit_revenue',
#        'unit_price', 'unit_liquid_price', 'unit_perc_pis_cofins',
#        'unit_perc_icms', 'unit_perc_tax_substitution', 'unit_liquid_cost',
#        'unit_markup', 'unit_liquid_cost_perc', 'weekend', 'week_of_month',
#        'quarter', 'cat_code'],
#       dtype='object')

# %%
catfields = ['source_channel', 'week_number', 'month', 'perc_pis_cofins', 'perc_icms','weekend', 'week_of_month', 'quarter']

# %%
def product_summary_building_ctabs(df, target_col, values_col='quantity', method = 'sum'):
    if method == 'mean':
        df_result = pd.crosstab(
            df['code'], df[target_col], 
            values=df[values_col], aggfunc=pd.Series.mean
        ).reset_index()
    else: 
        df_result = pd.crosstab(
            df['code'], df[target_col], 
            values=df[values_col], aggfunc=pd.Series.sum, normalize='index'
        ).reset_index()
                
    df_result.columns = ['code'] + [f'{target_col}_{values_col}_{col}' for col in df_result.columns if col not in ['code', target_col]]
    
    return df_result.fillna(0)

# %%
df_product_summary_catfields =  df_products.drop(columns=['cat_code'])
df_product_summary_catfields.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [e6762ba2ffbca07ab6cee7551caeaad5, d408e1b5e841dde4e15a4cfa182e3812, 29424aaf6e27a8dbe4b7273a0a39131d, 723f73c85e91fc31d147dfade389d4f9, 54209126056016c7c391c0c8fd8e6eff]

# %%
df_product_summary_catfields =  df_products.drop(columns=['cat_code'])
for catfield in catfields: 
    df = product_summary_building_ctabs(df_sales, catfield).set_index('code')
    df_product_summary_catfields = df_product_summary_catfields.join(df, on='code', how='left')

for catfield in catfields: 
    df = product_summary_building_ctabs(df_sales, catfield, values_col='markup', method='mean').set_index('code')
    df_product_summary_catfields = df_product_summary_catfields.join(df, on='code', how='left')

# %%
df_product_summary_catfields.head(10)
# Out:
#                                   source_channel_quantity_152bf0ce464047b9499ccb9e5b9b77a8  \
# code
# e6762ba2ffbca07ab6cee7551caeaad5                                           0.048780
# d408e1b5e841dde4e15a4cfa182e3812                                           0.013333
# 29424aaf6e27a8dbe4b7273a0a39131d                                           0.034091
# 723f73c85e91fc31d147dfade389d4f9                                           0.034000
# 54209126056016c7c391c0c8fd8e6eff                                           0.013746
# c443d252c048280160fc427766d9f1f4                                           0.014388
# 374e1947dcb8f4848f4ada6f04921edd                                           0.020710
# 60424117a2618c7184687046fa5693c4                                           0.000000
# 193628b6634713730d3c506f2da0ff58                                           0.014205
# d4592ab52cb9cd5af0510943a4c8e28c                                           0.012807
#
#                                   source_channel_quantity_2934a86a91bfa55d7f20b4f08a441fac  \
# code
# e6762ba2ffbca07ab6cee7551caeaad5                                                0.0
# d408e1b5e841dde4e15a4cfa182e3812                                                0.0
# 29424aaf6e27a8dbe4b7273a0a39131d                                                0.0
# 723f73c85e91fc31d147dfade389d4f9                                                0.0
# 54209126056016c7c391c0c8fd8e6eff                                                0.0
# c443d252c048280160fc427766d9f1f4                                                0.0
# 374e1947dcb8f4848f4ada6f04921edd                                                0.0
# 60424117a2618c7184687046fa5693c4                                                0.0
# 193628b6634713730d3c506f2da0ff58                                                0.0
# d4592ab52cb9cd5af0510943a4c8e28c                                                0.0
#
#                                   source_channel_quantity_3ab2427543039f8c9f17d06f6f65a3a7  \
# code
# e6762ba2ffbca07ab6cee7551caeaad5                                           0.000000
# d408e1b5e841dde4e15a4cfa182e3812                                           0.000000
# 29424aaf6e27a8dbe4b7273a0a39131d                                           0.000000
# 723f73c85e91fc31d147dfade389d4f9                                           0.000000
# 54209126056016c7c391c0c8fd8e6eff                                           0.000000
# c443d252c048280160fc427766d9f1f4                                           0.000000
# 374e1947dcb8f4848f4ada6f04921edd                                           0.002959
# 60424117a2618c7184687046fa5693c4                                           0.000000
# 193628b6634713730d3c506f2da0ff58                                           0.003472
# d4592ab52cb9cd5af0510943a4c8e28c                                           0.001067
#
#                                   source_channel_quantity_5a97b8efd901c1d28ff86522b95babb9  \
# code
# e6762ba2ffbca07ab6cee7551caeaad5                                           0.000000
# d408e1b5e841dde4e15a4cfa182e3812                                           0.026667
# 29424aaf6e27a8dbe4b7273a0a39131d                                           0
\
# code
# e6762ba2ffbca07ab6cee7551caeaad5                1.590829          1.634850
# d408e1b5e841dde4e15a4cfa182e3812                1.598775          1.807785
# 29424aaf6e27a8dbe4b7273a0a39131d                1.987136          1.874995
# 723f73c85e91fc31d147dfade389d4f9                1.316149          1.315990
# 54209126056016c7c391c0c8fd8e6eff                1.804965          1.856912
# c443d252c048280160fc427766d9f1f4                1.706112          1.696369
# 374e1947dcb8f4848f4ada6f04921edd                1.811664          1.764512
# 60424117a2618c7184687046fa5693c4                1.611387          1.792955
# 193628b6634713730d3c506f2da0ff58                1.777768          1.739147
# d4592ab52cb9cd5af0510943a4c8e28c                1.681035          1.670472
#
#                                   quarter_markup_2  quarter_markup_3  \
# code
# e6762ba2ffbca07ab6cee7551caeaad5          1.489590          1.642840
# d408e1b5e841dde4e15a4cfa182e3812          1.560464          1.499223
# 29424aaf6e27a8dbe4b7273a0a39131d          1.844339          2.048420
# 723f73c85e91fc31d147dfade389d4f9          1.339832          1.306918
# 54209126056016c7c391c0c8fd8e6eff          1.748652          1.657127
# c443d252c048280160fc427766d9f1f4          1.657040          1.595575
# 374e1947dcb8f4848f4ada6f04921edd          1.817734          1.814887
# 60424117a2618c7184687046fa5693c4          1.642197          1.886327
# 193628b6634713730d3c506f2da0ff58          1.790449          1.919633
# d4592ab52cb9cd5af0510943a4c8e28c          1.615460          1.812766
#
#                                   quarter_markup_4
# code
# e6762ba2ffbca07ab6cee7551caeaad5          1.399889
# d408e1b5e841dde4e15a4cfa182e3812          1.663810
# 29424aaf6e27a8dbe4b7273a0a39131d          2.035363
# 723f73c85e91fc31d147dfade389d4f9          1.298785
# 54209126056016c7c391c0c8fd8e6eff          1.741267
# c443d252c048280160fc427766d9f1f4          1.946876
# 374e1947dcb8f4848f4ada6f04921edd          1.639851
# 60424117a2618c7184687046fa5693c4          1.698261
# 193628b6634713730d3c506f2da0ff58          1.800982
# d4592ab52cb9cd5af0510943a4c8e28c          1.716636
#
# [10 rows x 226 columns]

# %%
for catfield in catfields: 
    print(catfield)
    print([col for col in df_product_summary_catfields.columns if catfield in col])
    print('')
# Out:
# source_channel
# ['source_channel_quantity_152bf0ce464047b9499ccb9e5b9b77a8', 'source_channel_quantity_2934a86a91bfa55d7f20b4f08a441fac', 'source_channel_quantity_3ab2427543039f8c9f17d06f6f65a3a7', 'source_channel_quantity_5a97b8efd901c1d28ff86522b95babb9', 'source_channel_quantity_67c19e107de33cab7ea9a9db8bc9ccd2', 'source_channel_quantity_7261d300057219056592010c7bdaf5ee', 'source_channel_quantity_98defd6ee70dfb1dea416cecdf391f58', 'source_channel_quantity_9d3e0fcbc1f16d80a76026e8f1c26002', 'source_channel_quantity_a578e71c3216f513a84ec6a46084fd3a', 'source_channel_quantity_af082bb0c2fa1414655017d464aa0262', 'source_channel_quantity_b76eb9b8fc0f17098812da9117d3e500', 'source_channel_quantity_e9b49f9086ba813ca3f0b321710fef16', 'source_channel_quantity_ea2912716be1999ab62d5b9dfa4f58f9', 'source_channel_quantity_fc7020775a7cdf161ab5267985c54601', 'source_channel_markup_152bf0ce464047b9499ccb9e5b9b77a8', 'source_channel_markup_2934a86a91bfa55d7f20b4f08a441fac', 'source_channel_markup_3ab2427543039f8c9f17d06f6f65a3a7', 'source_channel_markup_5a97b8efd901c1d28ff86522b95babb9', 'source_channel_markup_67c19e107de33cab7ea9a9db8bc9ccd2', 'source_channel_markup_7261d300057219056592010c7bdaf5ee', 'source_channel_markup_98defd6ee70dfb1dea416cecdf391f58', 'source_channel_markup_9d3e0fcbc1f16d80a76026e8f1c26002', 'source_channel_markup_a578e71c3216f513a84ec6a46084fd3a', 'source_channel_markup_af082bb0c2fa1414655017d464aa0262', 'source_channel_markup_b76eb9b8fc0f17098812da9117d3e500', 'source_channel_markup_e9b49f9086ba813ca3f0b321710fef16', 'source_channel_markup_ea2912716be1999ab62d5b9dfa4f58f9', 'source_channel_markup_fc7020775a7cdf161ab5267985c54601']
#
# week_number
# ['week_number_quantity_0', 'week_number_quantity_1', 'week_number_quantity_2', 'week_number_quantity_3', 'week_number_quantity_4', 'week_number_quantity_5', 'week_number_quantity_6', 'week_number_quantity_7', 'week_number_quantity_8', 'week_number_quantity_9', 'week_number_quantity_10', 'week_number_quantity_11', 'week_number_quantity_12', 'week_number_quantity_13', 'week_number_quantity_14', 'week_number_quantity_15', 'week_number_quantity_16', 'week_number_quantity_17', 'week_number_quantity_18', 'week_number_quantity_19', 'week_number_quantity_20', 'week_number_quantity_21', 'week_number_quantity_22', 'week_number_quantity_23', 'week_number_quantity_24', 'week_number_quantity_25', 'week_number_quantity_26', 'week_number_quantity_27', 'week_number_quantity_28', 'week_number_quantity_29', 'week_number_quantity_30', 'week_number_quantity_31', 'week_number_quantity_32', 'week_number_quantity_33', 'week_number_quantity_34', 'week_number_quantity_35', 'week_number_quantity_36', 'week_number_quantity_37', 'week_number_quantity_38', 'week_number_quantity_39', 'week_number_quantity_40', 'week_number_quantity_41', 'week_number_quantity_42', 'week_number_quantity_43', 'week_number_quantity_44', 'week_number_quantity_45', 'week_number_quantity_46', 'week_number_quantity_47', 'week_number_quantity_48', 'week_number_quantity_49', 'week_number_quantity_50', 'week_number_quantity_51', 'week_number_quantity_52', 'week_number_markup_0', 'week_number_markup_1', 'week_number_markup_2', 'week_number_markup_3', 'week_number_markup_4', 'week_number_markup_5', 'week_number_markup_6', 'week_number_markup_7', 'week_number_markup_8', 'week_number_markup_9', 'week_number_markup_10', 'week_number_markup_11', 'week_number_markup_12', 'week_number_markup_13', 'week_number_markup_14', 'week_number_markup_15', 'week_number_markup_16', 'week_number_markup_17', 'week_number_markup_18', 'week_number_markup_19', 'week_number_markup_20', 'week_number_markup_21', 'week_number_markup_22', 'week_number_markup_23', 'week_number_markup_24', 'week_number_markup_25', 'week_number_markup_26', 'week_number_markup_27', 'week_number_markup_28', 'week_number_markup_29', 'week_number_markup_30', 'week_number_markup_31', 'week_number_markup_32', 'week_number_markup_33', 'week_number_markup_34', 'week_number_markup_35', 'week_number_markup_36', 'week_number_markup_37', 'week_number_markup_38', 'week_number_markup_39', 'week_number_markup_40', 'week_number_markup_41', 'week_number_markup_42', 'week_number_markup_43', 'week_number_markup_44', 'week_number_markup_45', 'week_number_markup_46', 'week_number_markup_47', 'week_number_markup_48', 'week_number_markup_49', 'week_number_markup_50', 'week_number_markup_51', 'week_number_markup_52']
#
# month
# ['month_quantity_1', 'month_quantity_2', 'month_quantity_3', 'month_quantity_4', 'month_quantity_5', 'month_quantity_6', 'month_quantity_7', 'month_quantity_8', 'month_quantity_9', 'month_quantity_10', 'month_quantity_11', 'month_quantity_12', 'week_of_month_quantity_1', 'week_of_month_quantity_2', 'week_of_month_quantity_3', 'week_of_month_quantity_4', 'month_markup_1', 'month_markup_2', 'month_markup_3', 'month_markup_4', 'month_markup_5', 'month_markup_6', 'month_markup_7', 'month_markup_8', 'month_markup_9', 'month_markup_10', 'month_markup_11', 'month_markup_12', 'week_of_month_markup_1', 'week_of_month_markup_2', 'week_of_month_markup_3', 'week_of_month_markup_4']
#
# perc_pis_cofins
# ['perc_pis_cofins_quantity_0.0', 'perc_pis_cofins_quantity_9.25', 'perc_pis_cofins_markup_0.0', 'perc_pis_cofins_markup_9.25']
#
# perc_icms
# ['perc_icms_quantity_0.0', 'perc_icms_quantity_7.39', 'perc_icms_quantity_7.52', 'perc_icms_quantity_7.56', 'perc_icms_quantity_8.65', 'perc_icms_quantity_8.8', 'perc_icms_quantity_8.87', 'perc_icms_quantity_9.35', 'perc_icms_quantity_10.32', 'perc_icms_quantity_10.52', 'perc_icms_quantity_10.57', 'perc_icms_quantity_11.12', 'perc_icms_quantity_11.39', 'perc_icms_quantity_11.73', 'perc_icms_quantity_12.0', 'perc_icms_quantity_12.71', 'perc_icms_quantity_15.0', 'perc_icms_quantity_16.0', 'perc_icms_quantity_17.0', 'perc_icms_quantity_17.5', 'perc_icms_quantity_18.0', 'perc_icms_quantity_20.0', 'perc_icms_markup_0.0', 'perc_icms_markup_7.39', 'perc_icms_markup_7.52', 'perc_icms_markup_7.56', 'perc_icms_markup_8.65', 'perc_icms_markup_8.8', 'perc_icms_markup_8.87', 'perc_icms_markup_9.35', 'perc_icms_markup_10.32', 'perc_icms_markup_10.52', 'perc_icms_markup_10.57', 'perc_icms_markup_11.12', 'perc_icms_markup_11.39', 'perc_icms_markup_11.73', 'perc_icms_markup_12.0', 'perc_icms_markup_12.71', 'perc_icms_markup_15.0', 'perc_icms_markup_16.0', 'perc_icms_markup_17.0', 'perc_icms_markup_17.5', 'perc_icms_markup_18.0', 'perc_icms_markup_20.0']
#
# weekend
# ['weekend_quantity_0', 'weekend_quantity_1', 'weekend_markup_0', 'weekend_markup_1']
#
# week_of_month
# ['week_of_month_quantity_1', 'week_of_month_quantity_2', 'week_of_month_quantity_3', 'week_of_month_quantity_4', 'week_of_month_markup_1', 'week_of_month_markup_2', 'week_of_month_markup_3', 'week_of_month_markup_4']
#
# quarter
# ['quarter_quantity_1', 'quarter_quantity_2', 'quarter_quantity_3', 'quarter_quantity_4', 'quarter_markup_1', 'quarter_markup_2', 'quarter_markup_3', 'quarter_markup_4']

# %% [markdown]
# ## Numeric summaries

# %%
def percentile(n):
    def percentile_(x):
        return np.percentile(x, n)
    percentile_.__name__ = 'percentile_%s' % n
    return percentile_

## https://stackoverflow.com/questions/19894939/calculate-arbitrary-percentile-on-pandas-groupby

# %%
def numeric_summary(df, col):
    df_result = df[['code', col]].groupby('code').agg({
        col:['mean', 'std', 'max', 'min', percentile(50)]
    }).reset_index()
    df_result.columns = ['_'.join(tup).rstrip('_') for tup in df_result.columns.values]
    df_result = df_result.set_index('code')    
    return df_result
df = numeric_summary(df_sales, 'unit_markup')

df
# Out:
#                                   unit_markup_mean  unit_markup_std  \
# code
# 0671c2b9132a3f5215a4212ce0691694          1.562087         0.355623
# 09f544ec2a74c89abeec7b0590fc2d11          1.639085         0.344274
# 0ad316f6b5cb5e81ebff73ae2490ccfe          1.650388         0.348519
# 0bbe09e34a11e8e31cf49d6f8df2992d          1.470783         0.246788
# 0dca7ec6ba9b6e8f17f04f713a6be727          1.545965         0.429780
# ...                                            ...              ...
# f08984b2adcbf33ba61fe13fcfa5b957          1.726241         0.396015
# f5f92c2a12f182115c45288a6ef28e94          1.656365         0.338703
# f9a023f31c8087fd0c169b3bedd351d1          1.597636         0.331462
# fd84644da59504bd9e9dcb4b6db63bea          1.507804         0.349028
# ffdad3ddbaf6c76c9bba1b48c51e03c6          1.608984         0.305672
#
#                                   unit_markup_max  unit_markup_min  \
# code
# 0671c2b9132a3f5215a4212ce0691694         2.656474         1.087155
# 09f544ec2a74c89abeec7b0590fc2d11         2.528779         1.120780
# 0ad316f6b5cb5e81ebff73ae2490ccfe         2.480452         1.106237
# 0bbe09e34a11e8e31cf49d6f8df2992d         2.167081         1.096599
# 0dca7ec6ba9b6e8f17f04f713a6be727         3.038978         0.943613
# ...                                           ...              ...
# f08984b2adcbf33ba61fe13fcfa5b957         2.932773         0.841628
# f5f92c2a12f182115c45288a6ef28e94         2.340672         1.090410
# f9a023f31c8087fd0c169b3bedd351d1         2.254752         0.981598
# fd84644da59504bd9e9dcb4b6db63bea         2.292459         0.950428
# ffdad3ddbaf6c76c9bba1b48c51e03c6         2.496293         0.968685
#
#                                   unit_markup_percentile_50
# code
# 0671c2b9132a3f5215a4212ce0691694                   1.434718
# 09f544ec2a74c89abeec7b0590fc2d11                   1.561558
# 0ad316f6b5cb5e81ebff73ae2490ccfe                   1.553343
# 0bbe09e34a11e8e31cf49d6f8df2992d                   1.385264
# 0dca7ec6ba9b6e8f17f04f713a6be727                   1.487013
# ...                                                     ...
# f08984b2adcbf33ba61fe13fcfa5b957                   1.632953
# f5f92c2a12f182115c45288a6ef28e94                   1.769399
# f9a023f31c8087fd0c169b3bedd351d1                   1.587459
# fd84644da59504bd9e9dcb4b6db63bea                   1.398620
# ffdad3ddbaf6c76c9bba1b48c51e03c6                   1.699506
#
# [130 rows x 5 columns]

# %%
numeric_cols = ['unit_liquid_cost_perc',
       'unit_markup']
df_product_summary_numeric =  df_products.drop(columns=['cat_code'])

for col in numeric_cols: 
    df = numeric_summary(df_sales, col)
    df_product_summary_numeric = df_product_summary_numeric.join(df, on='code', how='left')

# %%
df_product_summary_numeric.head()
# Out:
#                                   unit_liquid_cost_perc_mean  \
# code
# e6762ba2ffbca07ab6cee7551caeaad5                    0.664485
# d408e1b5e841dde4e15a4cfa182e3812                    0.667039
# 29424aaf6e27a8dbe4b7273a0a39131d                    0.547610
# 723f73c85e91fc31d147dfade389d4f9                    0.767880
# 54209126056016c7c391c0c8fd8e6eff                    0.586322
#
#                                   unit_liquid_cost_perc_std  \
# code
# e6762ba2ffbca07ab6cee7551caeaad5                   0.139084
# d408e1b5e841dde4e15a4cfa182e3812                   0.168905
# 29424aaf6e27a8dbe4b7273a0a39131d                   0.128811
# 723f73c85e91fc31d147dfade389d4f9                   0.063620
# 54209126056016c7c391c0c8fd8e6eff                   0.113344
#
#                                   unit_liquid_cost_perc_max  \
# code
# e6762ba2ffbca07ab6cee7551caeaad5                   0.873420
# d408e1b5e841dde4e15a4cfa182e3812                   0.904901
# 29424aaf6e27a8dbe4b7273a0a39131d                   0.741435
# 723f73c85e91fc31d147dfade389d4f9                   1.014705
# 54209126056016c7c391c0c8fd8e6eff                   0.897872
#
#                                   unit_liquid_cost_perc_min  \
# code
# e6762ba2ffbca07ab6cee7551caeaad5                   0.495834
# d408e1b5e841dde4e15a4cfa182e3812                   0.198069
# 29424aaf6e27a8dbe4b7273a0a39131d                   0.209398
# 723f73c85e91fc31d147dfade389d4f9                   0.353106
# 54209126056016c7c391c0c8fd8e6eff                   0.263493
#
#                                   unit_liquid_cost_perc_percentile_50  \
# code
# e6762ba2ffbca07ab6cee7551caeaad5                             0.713632
# d408e1b5e841dde4e15a4cfa182e3812                             0.739112
# 29424aaf6e27a8dbe4b7273a0a39131d                             0.573237
# 723f73c85e91fc31d147dfade389d4f9                             0.768454
# 54209126056016c7c391c0c8fd8e6eff                             0.544282
#
#                                   unit_markup_mean  unit_markup_std  \
# code
# e6762ba2ffbca07ab6cee7551caeaad5          1.574080         0.339841
# d408e1b5e841dde4e15a4cfa182e3812          1.441776         0.275338
# 29424aaf6e27a8dbe4b7273a0a39131d          1.791870         0.389380
# 723f73c85e91fc31d147dfade389d4f9          1.307263         0.099146
# 54209126056016c7c391c0c8fd8e6eff          1.749869         0.313052
#
#                                   unit_markup_max  unit_markup_min  \
# code
# e6762ba2ffbca07ab6cee7551caeaad5         2.016804         1.144924
# d408e1b5e841dde4e15a4cfa182e3812         1.999516         1.105093
# 29424aaf6e27a8dbe4b7273a0a39131d         2.791206         1.294306
# 723f73c85e91fc31d147dfade389d4f9         1.637204         0.985509
# 54209126056016c7c391c0c8fd8e6eff         2.351887         1.113744
#
#                                   unit_markup_percentile_50
# code
# e6762ba2ffbca07ab6cee7551caeaad5                   1.401282
# d408e1b5e841dde4e15a4cfa182e3812                   1.334629
# 29424aaf6e27a8dbe4b7273a0a39131d                   1.574516
# 723f73c85e91fc31d147dfade389d4f9                   1.301313
# 54209126056016c7c391c0c8fd8e6eff                   1.798905

# %%
df_products_final = df_products.join(df_product_summary_catfields, on='code', how='left')
df_products_final = df_products_final.join(df_product_summary_numeric, on='code', how='left')
df_products_final.head()
# Out:
#                                   cat_code  \
# code
# e6762ba2ffbca07ab6cee7551caeaad