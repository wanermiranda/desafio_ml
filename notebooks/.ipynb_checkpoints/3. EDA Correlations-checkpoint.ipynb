# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np 
import seaborn as sns
sns.set(rc={'figure.figsize':(20,8)})
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

pd.set_option('display.max_rows', 120)

# %% [markdown]
# ## Reading / Displaying the Data

# %%
df_sales = pd.read_csv('../data/clean_step2.csv')

# %%
df_sales.head()
# Out:
#                            order_id                              code  \
# 0  bcb59c839e78b2601374cbad9239ca7b  e6762ba2ffbca07ab6cee7551caeaad5
# 1  88eb0ac86af1a521c0831298d22dea8b  e6762ba2ffbca07ab6cee7551caeaad5
# 2  1c175bc61b9b659bbf011b2e5e3dcec6  e6762ba2ffbca07ab6cee7551caeaad5
# 3  a8ad36828898fa3f6efeb5bd19c076f2  e6762ba2ffbca07ab6cee7551caeaad5
# 4  9cbfaac6e04ea6ed454b843c94f2c29c  e6762ba2ffbca07ab6cee7551caeaad5
#
#    quantity    price  pis_cofins     icms  tax_substitution  \
# 0         1   978.90     90.5483    0.000          191.8416
# 1         1   978.90     90.5483    0.000          191.8416
# 2         1   976.05     90.2846    0.000          192.3325
# 3         1  1089.10    100.7418  185.147            0.0000
# 4         1   949.00     87.7825  170.820            0.0000
#
#                            category  liquid_cost   order_status capture_date  \
# 0  4ece547755cba9e7fc14125bc895f31b     542.7065  entrega total   2016-06-11
# 1  4ece547755cba9e7fc14125bc895f31b     542.7065  entrega total   2016-06-12
# 2  4ece547755cba9e7fc14125bc895f31b     542.7065  entrega total   2016-06-13
# 3  4ece547755cba9e7fc14125bc895f31b     542.7065  entrega total   2016-06-13
# 4  4ece547755cba9e7fc14125bc895f31b     542.7065  entrega total   2016-06-14
#
#   process_date process_status                    source_channel   revenue  \
# 0   2016-06-11     processado  b76eb9b8fc0f17098812da9117d3e500  436.1935
# 1   2016-06-12     processado  b76eb9b8fc0f17098812da9117d3e500  436.1935
# 2   2016-06-13     processado  b76eb9b8fc0f17098812da9117d3e500  433.3435
# 3   2016-06-13     processado  9d3e0fcbc1f16d80a76026e8f1c26002  546.3935
# 4   2016-06-14     processado  7261d300057219056592010c7bdaf5ee  406.2935
#
#      markup  week_number  month  unit_revenue
# 0  0.803737           23      6      436.1935
# 1  0.803737           23      6      436.1935
# 2  0.798486           24      6      433.3435
# 3  1.006794           24      6      546.3935
# 4  0.748643           24      6      406.2935

# %%
df_sales.describe(percentiles=[.0001,.25, .50, .75, .90, .99, .9999])
# Out:
#              quantity          price     pis_cofins           icms  \
# count   144731.000000  144731.000000  144731.000000  144731.000000
# mean         1.050653     233.439841      19.446323      24.590919
# std          0.405702     154.475453      15.034110      29.380116
# min          1.000000       6.910000       0.000000       0.000000
# 0.01%        1.000000       6.910000       0.000000       0.000000
# 25%          1.000000     149.410000      10.430300       0.000000
# 50%          1.000000     194.800000      17.519500      19.880000
# 75%          1.000000     309.900000      28.618600      38.860200
# 90%          1.000000     359.910000      33.244500      61.098000
# 99%          2.000000     820.567000      70.280660     131.220000
# 99.99%      15.000000    3336.680500     308.642973     463.352603
# max         20.000000    7950.000000     735.375000    1220.400000
#
#         tax_substitution    liquid_cost        revenue         markup  \
# count      144731.000000  144731.000000  144731.000000  144731.000000
# mean           18.274328     135.678992      97.760848       0.805955
# std            28.044705      81.685219     102.029945       0.754525
# min             0.000000       4.114100     -66.483700      -0.289836
# 0.01%           0.000000       4.114100      -4.614900      -0.028274
# 25%             0.000000      76.865400      55.375100       0.545132
# 50%             0.000000     117.082000      79.323500       0.696978
# 75%            30.861200     205.899700     115.971800       0.897382
# 90%            69.057300     213.438200     155.961800       1.110051
# 99%           100.815700     496.929700     421.293500       3.125190
# 99.99%        280.435469     896.681400    3121.671592      27.760943
# max           280.617400     896.681400    7562.884600      56.853730
#
#           week_number          month   unit_revenue
# count   144731.000000  144731.000000  144731.000000
# mean        25.741002       6.385391      90.545141
# std         15.982790       3.636626      54.681284
# min          0.000000       1.000000     -66.483700
# 0.01%        0.000000       1.000000      -4.614900
# 25%         12.000000       3.000000      54.795300
# 50%         24.000000       6.000000      78.584500
# 75%         41.000000      10.000000     113.653800
# 90%         47.000000      11.000000     150.961800
# 99%         52.000000      12.000000     291.205000
# 99.99%      52.000000      12.000000     781.581900
# max         52.000000      12.000000    1101.758600

# %% [markdown]
# ## Verify the distributions

# %%
def summary_dist(target_col, base_col='order_id', method='count'):
    if method == 'count':
        df_summary = df_sales[[target_col,base_col]].groupby(target_col).agg({base_col:pd.Series.nunique}).reset_index()
    else:
        df_summary = df_sales[[target_col,base_col]].groupby(target_col).agg({base_col:pd.Series.sum}).reset_index()
    df_summary[base_col] = df_summary[base_col] / df_summary[base_col].sum()  * 100
    return df_summary.sort_values(base_col).tail(25)

# %%
df_orders_product = summary_dist('code')
df_orders_product
# Out:
#                                  code   order_id
# 64   5e4c14883e5a606fac56b2630da5dca7   0.771777
# 46   4557c7e5af70efd2e3ca2befd59ccdc3   0.807014
# 89   a2018dae10d736a66eea5a0a349ef9ee   0.815306
# 103  c254dc11afbcc091678f0ab49a02e7ad   0.858144
# 73   6c82ad0e791258434fd42c51409b0239   0.875417
# 5    0f38be2df6854b4374f06cae1bc38482   0.952111
# 39   40bddb00475d65eddb68e9aeb6fab0de   0.997713
# 121  e13f7f001fe2b1af072a3d50d3058284   1.080625
# 81   7da116bd1d42f3475803402e710253cf   1.162156
# 63   5e39201e582b1bb89cae7f650e4330c8   1.238850
# 128  fd84644da59504bd9e9dcb4b6db63bea   1.661703
# 9    193628b6634713730d3c506f2da0ff58   2.112885
# 95   b08b7321c4db8f45a1a97a79d1e44dd8   2.137759
# 77   727673fa3e457bc596532b3eb26b23a0   2.146741
# 88   a0c96bb1b4117eeeae27b77a1381f55f   2.229654
# 117  d5bc9e14d090330cd07e6ccbcb3c3e4e   2.295293
# 79   760693745e10b0c5e68c42214c729b0d   2.749929
# 0    0671c2b9132a3f5215a4212ce0691694   2.868079
# 116  d57911cca4b08f7b46417d952c0ca1dc   3.328243
# 61   5b7a30a9e6a43b170ad4d9e00d8d9359   3.476104
# 17   23056d85a1c9115cd021a6ad35c84aff   3.555562
# 25   32ceebf3efea1d04ace4183d20d4da5b   5.175809
# 26   3454ea52396a4cfd3fc37414d30c7b9c   5.188246
# 44   4534ea61b50410b3b6243e02b40c8cd1   9.814760
# 23   2e35421c34fb588ba40a0c57b3971d24  12.454830

# %%
df_orders_product.tail(10).sum()
# Out:
# code        d5bc9e14d090330cd07e6ccbcb3c3e4e760693745e10b0...
# order_id                                              50.9069
# dtype: object

# %% [markdown]
# * It is interesting to see that 50% of the orders are from 10 Products

# %%
df_product_quantity = summary_dist('code', base_col='quantity', method='sum')
df_product_quantity
# Out:
#                                  code   quantity
# 64   5e4c14883e5a606fac56b2630da5dca7   0.756928
# 46   4557c7e5af70efd2e3ca2befd59ccdc3   0.781260
# 89   a2018dae10d736a66eea5a0a349ef9ee   0.806908
# 73   6c82ad0e791258434fd42c51409b0239   0.843077
# 5    0f38be2df6854b4374f06cae1bc38482   0.941721
# 103  c254dc11afbcc091678f0ab49a02e7ad   0.967369
# 39   40bddb00475d65eddb68e9aeb6fab0de   0.977891
# 121  e13f7f001fe2b1af072a3d50d3058284   1.087057
# 81   7da116bd1d42f3475803402e710253cf   1.135721
# 63   5e39201e582b1bb89cae7f650e4330c8   1.350765
# 128  fd84644da59504bd9e9dcb4b6db63bea   1.653273
# 9    193628b6634713730d3c506f2da0ff58   2.083361
# 95   b08b7321c4db8f45a1a97a79d1e44dd8   2.115584
# 77   727673fa3e457bc596532b3eb26b23a0   2.167537
# 88   a0c96bb1b4117eeeae27b77a1381f55f   2.198445
# 117  d5bc9e14d090330cd07e6ccbcb3c3e4e   2.318133
# 79   760693745e10b0c5e68c42214c729b0d   2.708106
# 0    0671c2b9132a3f5215a4212ce0691694   2.794255
# 61   5b7a30a9e6a43b170ad4d9e00d8d9359   3.374939
# 116  d57911cca4b08f7b46417d952c0ca1dc   3.394010
# 17   23056d85a1c9115cd021a6ad35c84aff   3.466349
# 25   32ceebf3efea1d04ace4183d20d4da5b   5.020978
# 26   3454ea52396a4cfd3fc37414d30c7b9c   5.185385
# 44   4534ea61b50410b3b6243e02b40c8cd1  10.159014
# 23   2e35421c34fb588ba40a0c57b3971d24  12.279860

# %%
df_product_quantity.tail(10).sum()
# Out:
# code        d5bc9e14d090330cd07e6ccbcb3c3e4e760693745e10b0...
# quantity                                               50.701
# dtype: object

# %% [markdown]
# * It is interesting to see that also 50% of  the quantity are from 10 Products

# %%
df_product_revenue = summary_dist('code', base_col='revenue', method='sum')
df_product_revenue
# Out:
#                                  code    revenue
# 9    193628b6634713730d3c506f2da0ff58   0.814967
# 31   37e2a39e829495d13b6cbb5320413e48   0.837144
# 119  dd1935ffd0ee2b6ec159ba7867d11e57   0.905170
# 50   4ceedf57303e127d31a164c7ae5791d8   0.996237
# 5    0f38be2df6854b4374f06cae1bc38482   1.003183
# 93   abf2d3cb446492ee7897087db9a0b2a0   1.123538
# 46   4557c7e5af70efd2e3ca2befd59ccdc3   1.136976
# 81   7da116bd1d42f3475803402e710253cf   1.139122
# 12   1c234775cae774823f38abe6721e61a4   1.296057
# 82   7e3713530b46887cff58a2e2ac433ac5   1.308157
# 116  d57911cca4b08f7b46417d952c0ca1dc   1.401368
# 88   a0c96bb1b4117eeeae27b77a1381f55f   1.756150
# 57   55447a73ff140176f4210347854c71f1   1.930668
# 77   727673fa3e457bc596532b3eb26b23a0   1.988593
# 17   23056d85a1c9115cd021a6ad35c84aff   2.057412
# 95   b08b7321c4db8f45a1a97a79d1e44dd8   2.064029
# 117  d5bc9e14d090330cd07e6ccbcb3c3e4e   2.101149
# 128  fd84644da59504bd9e9dcb4b6db63bea   2.262080
# 61   5b7a30a9e6a43b170ad4d9e00d8d9359   2.610806
# 0    0671c2b9132a3f5215a4212ce0691694   2.912810
# 79   760693745e10b0c5e68c42214c729b0d   3.978841
# 26   3454ea52396a4cfd3fc37414d30c7b9c   5.041394
# 25   32ceebf3efea1d04ace4183d20d4da5b   7.405570
# 44   4534ea61b50410b3b6243e02b40c8cd1   7.922350
# 23   2e35421c34fb588ba40a0c57b3971d24  16.645397

# %%
df_product_revenue.tail(10).sum()
# Out:
# code       b08b7321c4db8f45a1a97a79d1e44dd8d5bc9e14d09033...
# revenue                                              52.9444
# dtype: object

# %% [markdown]
# * Now when we have that 3 products represent 30% of the revenue ?

# %% [markdown]
# ## Deep dive on products

# %%
top_5_orders = df_orders_product.tail(5).code.values
top_5_product_revenue = df_product_revenue.tail(5).code.values
top_5_product_quantity = df_product_quantity.tail(5).code.values

selected_products = list(set(list(top_5_orders)+ list(top_5_product_revenue)+ list(top_5_product_quantity)))
selected_products
# Out:
# ['760693745e10b0c5e68c42214c729b0d',
#  '4534ea61b50410b3b6243e02b40c8cd1',
#  '23056d85a1c9115cd021a6ad35c84aff',
#  '32ceebf3efea1d04ace4183d20d4da5b',
#  '3454ea52396a4cfd3fc37414d30c7b9c',
#  '2e35421c34fb588ba40a0c57b3971d24']

# %%
df_filtered_sales = df_sales[df_sales.code.isin(selected_products)]
df_filtered_sales.groupby('code').describe(percentiles=[.0001,.25, .50, .75, .90, .99, .9999]).T
# Out:
# code                 23056d85a1c9115cd021a6ad35c84aff  \
# quantity     count                        5146.000000
#              mean                            1.024291
#              std                             0.187025
#              min                             1.000000
#              0.01%                           1.000000
# ...                                               ...
# unit_revenue 75%                            63.442400
#              90%                            77.322400
#              99%                            92.064860
#              99.99%                        170.919085
#              max                           177.136200
#
# code                 2e35421c34fb588ba40a0c57b3971d24  \
# quantity     count                       18026.000000
#              mean                            1.035893
#              std                             0.242248
#              min                             1.000000
#              0.01%                           1.000000
# ...                                               ...
# unit_revenue 75%                           145.961800
#              90%                           155.961800
#              99%                           244.885765
#              99.99%                        345.846104
#              max                           400.061800
#
# code                 32ceebf3efea1d04ace4183d20d4da5b  \
# quantity     count                        7491.000000
#              mean                            1.019223
#              std                             0.159786
#              min                             1.000000
#              0.01%                           1.000000
# ...                                               ...
# unit_revenue 75%                           153.500300
#              90%                           183.500300
#              99%                           256.869300
#              99.99%                        364.235772
#              max                           396.450150
#
# code                 3454ea52396a4cfd3fc37414d30c7b9c  \
# quantity     count                        7509.000000
#              mean                            1.050073
#              std                             0.523702
#              min                             1.000000
#              0.01%                           1.000000
# ...                                               ...
# unit_revenue 75%                           103.264300
#              90%                           111.224580
#              99%                           161.699922
#              99.99%                        236.216692
#              max                           257.434300
#
# code                 4534ea61b50410b3b6243e02b40c8cd1  \
# quantity     count                       14205.000000
#              mean                            1.087504
#              std                             0.523742
#              min                             1.000000
#              0.01%                           1.000000
# ...                                               ...
# unit_revenue 75%                            74.103500
#              90%                            90.293500
#              99%                           144.626750
#              99.99%                        201.786787
#              max                           230.853500
#
# code                 760693745e10b0c5e68c42214c729b0d
# quantity     count                        3980.000000
#              mean                            1.034673
#              std                             0.247234
#              min                             1.000000
#              0.01%                           1.000000
# ...                                               ...
# unit_revenue 75%                           144.200300
#              90%                           183.100300
#              99%                           261.569882
#              99.99%                        361.094497
#              max                           365.300300
#
# [132 rows x 6 columns]

# %% [markdown]
# * The products are selling in orders with 1 quantity 90% of the time.
# * The price deviation on 3454ea52396a4cfd3fc37414d30c7b9c and 4534ea61b50410b3b6243e02b40c8cd1 when compared to its means have a higher value than its pairs.
# * The product 4534ea61b50410b3b6243e02b40c8cd1 doesn't have to pay pis/cofins.
# * 75% of the sales for 760693745e10b0c5e68c42214c729b0d doens't do tax substitution.
# * The product costs doesn't change?
# * There were some sales with negative revenue (losses) 4534ea61b50410b3b6243e02b40c8cd1 and 2e35421c34fb588ba40a0c57b3971d24.

# %% [markdown]
# ## Season

# %%
def plot_season_sales(df, target_col, base_col='month', method='sum'):
    if method == 'sum':
        df = df[[base_col, target_col]].groupby(base_col).sum().reset_index()
    else: 
        df = df[[base_col, target_col]].groupby(base_col).mean().reset_index()
    return sns.lineplot(x=df[base_col], y=df[target_col])

# %%
ax = plot_season_sales(df_filtered_sales,'quantity')
plt.show()

# %%
for prod in selected_products: 
    df = df_filtered_sales[df_filtered_sales.code == prod]
    ax = plot_season_sales(df,'revenue', base_col='week_number')
    ax.set_title(prod)
    plt.show()

# %% [markdown]
# ## Revenue
# * 345 peas around jan, april, early may, august, september, oct, november, december. Very non-monotonic curve.
# * 32c peas around jan, april, early may, june, august, oct, november, december. Very non-monotonic curve.
# * 2e3 a decrease in sales by weeks 30 to 40.
# * 453 a decrease in sales by weeks 10 to 20 and 30 to 40.
# * 760, high peaks on 10, 20  30 and 40.
# * 230 peaks on 20, 25 to 30 35, 40 and around 45.

# %% [markdown]
# ## Price sensibility

# %%
def plot_price_sensibility(df, target_col, base_col='month', title=''):
    df = df[[base_col, target_col, 'quantity']].groupby(base_col).agg({target_col:'mean', 'quantity':'sum'}).reset_index()    
    fig, ax = plt.subplots()
    sns.lineplot(x=df[base_col], y=df[target_col], ax=ax, color='red')
    ax2 = ax.twinx()
    sns.lineplot(x=df[base_col], y=df['quantity'], ax=ax2)
    sns.despine(ax=ax, right=True, left=True)
    sns.despine(ax=ax2, left=True, right=False)
    ax2.spines['right'].set_color('white')

    ax.set_title(title)

# %%
for prod in selected_products: 
    df = df_filtered_sales[df_filtered_sales.code == prod]
    ax = plot_price_sensibility(df,'unit_revenue', base_col='week_number', title=prod)
    plt.show()

# %% [markdown]
# * The price tends to have an inverse proportion of the sales volume .
